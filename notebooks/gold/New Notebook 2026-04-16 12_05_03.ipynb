# %%
from pyspark.sql.functions import *

df_bronze = spark.read.format("delta").load("/Volumes/workspace/default/banking-transactions-lakehouse-project-selected-dataset-edition/delta/bronze/transactions")

df_bronze.display()
